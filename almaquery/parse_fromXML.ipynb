# %%
from xml.etree import ElementTree as ET

# %%
tree = ET.parse("lala.xml")

# %%
root = tree.getroot()

# %%
for obs in root[0][0][0][2][36][0]:
    for data in obs:
        print data.text,
    print "\n"
# Out:
# 2011.0.00101.S J1229+020; 3c273 187.27791249999999 2.052388333333333 289.95092048075674 64.35992752794299 7 0.93868320027921393 31250.0 12m None 30.24 2013-05-01 [336.99..338.99GHz,31250.00kHz, XX YY] U [338.93..340.93GHz,31250.00kHz, XX YY] U [348.99..350.99GHz,31250.00kHz, XX YY] U [350.99..352.99GHz,31250.00kHz, XX YY] 27158.00096285598 XX YY 2012-01-12 08:57:16 Wang, Wei-Hao GRB080607 Huang, Kuiyun; Chen, Hsiao-Wen; 16.364955573091137 0.6371131134582908 0.7758382 None uid://A001/X74/X27 uid://A002/X36bf6c/X58a Shedding Light on Distant Starburst Galaxies Hosting Gamma-ray Bursts v9 S BANDPASS PHASE WVR 18.26115671529038 4.361853437050275 Y 2 Starburst galaxies, Gamma Ray Bursts (GRB) Active galaxies 2011.0.00101.S
#
# ...
