# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
y = (0.5)*np.random.random(1000) + (1-0.25)
x = np.arange(0, 1000)

# %%
plt.plot(x, y, 'k')
plt.ylim([0.0, 1.5])
# Out:
# (0.0, 1.5)

# %%
ymean = y.mean()
yrms = y.std()

print ymean
print yrms
# Out:
# 0.992966166042
# 0.143860237833

# %%
plt.hist(np.sqrt((y/yrms)**2))
# Out:
# (array([ 109.,  106.,  100.,   99.,  109.,   92.,  103.,  101.,   84.,   97.]),
#  array([ 5.21610816,  5.56225274,  5.90839733,  6.25454191,  6.6006865 ,
#          6.94683108,  7.29297566,  7.63912025,  7.98526483,  8.33140941,
#          8.677554  ]),
#  <a list of 10 Patch objects>)

# %%
# ?np.std
