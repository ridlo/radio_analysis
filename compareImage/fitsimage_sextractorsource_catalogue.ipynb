# %%
import os
import numpy as np
from astropy import units as u 
from astropy import coordinates
from astropy.io import fits
import matplotlib.pyplot as plt
import aplpy

# %matplotlib inline

# %%
#imagename = 'images/2MASS-J.fits'
imagename = 'onlygood.ms.cont.image.fits'

# %%
hdu_list = fits.open(imagename)
hdu_list.info()
# Out:
# Filename: onlygood.ms.cont.image.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU    2924   (960, 960, 1, 1)   float32

# %%
hdu_list[0].header
# Out:
# SIMPLE  =                    T /Standard FITS
# BITPIX  =                  -32 /Floating point (32 bit)
# NAXIS   =                    4
# NAXIS1  =                  960
# NAXIS2  =                  960
# NAXIS3  =                    1
# NAXIS4  =                    1
# EXTEND  =                    T
# BSCALE  =   1.000000000000E+00 /PHYSICAL = PIXEL*BSCALE + BZERO
# BZERO   =   0.000000000000E+00
# BMAJ    =   9.142479134931E-05
# BMIN    =   6.217141118315E-05
# BPA     =   7.661312103271E+01
# BTYPE   = 'Intensity'
# OBJECT  = 'J0423-0120'
#
# BUNIT   = 'Jy/beam '           /Brightness (pixel) unit
# EQUINOX =   2.000000000000E+03
# RADESYS = 'FK5     '
# LONPOLE =   1.800000000000E+02
# LATPOLE =  -1.342518194444E+00
# PC01_01 =   1.000000000000E+00
# PC02_01 =   0.000000000000E+00
# PC03_01 =   0.000000000000E+00
# PC04_01 =   0.000000000000E+00
# PC01_02 =   0.000000000000E+00
# PC02_02 =   1.000000000000E+00
# PC03_02 =   0.000000000000E+00
# PC04_02 =   0.000000000000E+00
# ...

# %%
image_data = hdu_list[0].data
print type(image_data)
print image_data.shape
print image_data[0][0].shape
# Out:
# <type 'numpy.ndarray'>
# (1, 1, 960, 960)
# (960, 960)

# %%
fig = aplpy.FITSFigure('images/2MASS-J.fits')
fig.add_grid()

data = np.loadtxt('point_source.dat')
ra, dec = data[:, 0], data[:, 1]

fig.show_markers(ra, dec, layer='marker_set_1', edgecolor='white', facecolor='none', marker='o', s=100, alpha=0.5)

fig.show_colorscale()
#fig.show_grayscale()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-edfb55b2768b> in <module>()
#       1 fig = aplpy.FITSFigure('images/2MASS-J.fits')
# ----> 2 fig.add_beam()
#       3 fig.add_grid()
#       4
#       5 data = np.loadtxt('point_source.dat')
#
# /home/ridlo/anaconda2/lib/python2.7/site-packages/aplpy/core.pyc in add_beam(self, *args, **kwargs)
#
# /home/ridlo/anaconda2/lib/python2.7/site-packages/aplpy/decorators.pyc in _auto_refresh(f, *args, **kwargs)
#      23     mydata.nesting = getattr(mydata, 'nesting', 0) + 1
#      24     try:
# ---> 25         return f(*args, **kwargs)
#      26     finally:
#      27         mydata.nesting -= 1
#
# /home/ridlo/anaconda2/lib/python2.7/site-packages/aplpy/core.pyc in add_beam(self, *args, **kwargs)
#    1883         # Initalize the beam and set parameters
#    1884         b = Beam(self)
# ...

# %%
fig.list_layers()
# Out:
#   There is one layer in this figure:
#
#    -> marker_set_1

# %%
fig.refresh()
fig.show_colorscale()
# Out:
# INFO: Auto-setting vmin to  9.321e+01 [aplpy.core]
# INFO: Auto-setting vmax to  1.616e+02 [aplpy.core]

# %%
help(aplpy.FITSFigure)
# Out:
# Help on class FITSFigure in module aplpy.core:
#
# class FITSFigure(aplpy.layers.Layers, aplpy.regions.Regions, aplpy.deprecated.Deprecated)
#  |  A class for plotting FITS files.
#  |
#  |  Method resolution order:
#  |      FITSFigure
#  |      aplpy.layers.Layers
#  |      aplpy.regions.Regions
#  |      aplpy.deprecated.Deprecated
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, data, hdu=0, figure=None, subplot=(1, 1, 1), downsample=False, north=False, convention=None, dimensions=[0, 1], slices=[], auto_refresh=None, **kwargs)
#  |      Create a FITSFigure instance.
#  |
#  |      Parameters
#  |      ----------
#  |
#  |      data : see below
#  |
#  |          The FITS file to open. The following data types can be passed:
#  |
#  |               string
#  |               astropy.io.fits.PrimaryHDU
#  |               astropy.io.fits.ImageHDU
#  |               astropy.wcs.WCS
#  |               np.ndarray
# ...

# %%
dir(fig)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_auto_v',
#  '_ax1',
#  '_ax2',
#  '_circle_counter',
#  '_contour_counter',
#  '_data',
#  '_ellipse_counter',
#  '_extent',
#  '_figure',
#  '_get_colormap_default',
#  '_get_hdu',
#  '_get_invert_default',
#  '_header',
#  '_initialize_layers',
#  '_initialize_view',
#  '_label_counter',
#  '_layer_type',
#  '_layers',
#  '_linelist_counter',
#  '_parameters',
#  '_poly_counter',
#  '_rectangle_counter',
#  '_region_counter',
#  '_scatter_counter',
#  '_vector_counter',
#  '_wcs',
#  'add_beam',
#  'add_colorbar',
#  'add_grid',
#  'add_label',
#  'add_scalebar',
#  'axis_labels',
#  'close',
#  'frame',
#  'get_layer',
#  'hide_axis_labels',
#  'hide_beam',
#  'hide_colorbar',
# ...
